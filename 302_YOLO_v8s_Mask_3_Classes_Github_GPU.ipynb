# %% [markdown]
# # YOLO_v8s Custom Dataset (3 Classes)
#
# * https://github.com/ultralytics/ultralytics
# * https://docs.ultralytics.com/models/yolov8

# %% [markdown]
# # GPU 정보 확인

# %%
# !nvidia-smi
# Out:
# Tue Aug 25 06:14:39 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# # colab OS 확인

# %%
# !lsb_release -a
# Out:
# No LSB modules are available.
# Distributor ID:	Ubuntu
# Description:	Ubuntu 22.04.5 LTS
# Release:	22.04
# Codename:	jammy

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # I. Custom Data_Set
#
# * 3 Classes

# %% [markdown]
# >## 1) wget From Github
#
# * 'maskdataset_3C.tar' 파일 다운로드

# %%
# !wget https://raw.githubusercontent.com/rusita-ai/pyData/master/maskdataset_3C.tara{a,b,c,d,e}
# Out:
# --2026-08-25 01:18:06--  https://raw.githubusercontent.com/rusita-ai/pyData/master/maskdataset_3C.taraa
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 94371840 (90M) [application/octet-stream]
# Saving to: ‘maskdataset_3C.taraa.1’
#
# maskdataset_3C.tara 100%[===================>]  90.00M   219MB/s    in 0.4s
#
# 2026-08-25 01:18:10 (219 MB/s) - ‘maskdataset_3C.taraa.1’ saved [94371840/94371840]
#
# --2026-08-25 01:18:10--  https://raw.githubusercontent.com/rusita-ai/pyData/master/maskdataset_3C.tarab
# Reusing existing connection to raw.githubusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 94371840 (90M) [application/octet-stream]
# Saving to: ‘maskdataset_3C.tarab.1’
#
# maskdataset_3C.tara 100%[===================>]  90.00M   221MB/s    in 0.4s
#
# 2026-08-25 01:18:13 (221 MB/s) - ‘maskdataset_3C.tarab.1’ saved [94371840/94371840]
#
# --2026-08-25 01:18:13--  https://raw.githubusercontent.com/rusita-ai/pyData/master/maskdataset_3C.tarac
# Reusing existing connection to raw.githubusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 94371840 (90M) [application/octet-stream]
# Saving to: ‘maskdataset_3C.tarac.1’
#
# maskdataset_3C.tara 100%[===================>]  90.00M   168MB/s    in 0.5s
#
# 2026-08-25 01:18:16 (168 MB/s) - ‘maskdataset_3C.tarac.1’ saved [94371840/94371840]
#
# --2026-08-25 01:18:16--  https://raw.githubusercontent.com/rusita-ai/pyData/master/maskdataset_3C.tarad
# Reusing existing connection to raw.githubusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 94371840 (90M) [application/octet-stream]
# Saving to: ‘maskdataset_3C.tarad.1’
#
# maskdataset_3C.tara 100%[===================>]  90.00M   138MB/s    in 0.7s
#
# 2026-08-25 01:18:18 (138 MB/s) - ‘maskdataset_3C.tarad.1’ saved [94371840/94371840]
#
# --2026-08-25 01:18:18--  https://raw.githubusercontent.com/rusita-ai/pyData/master/maskdataset_3C.tarae
# Reusing existing connection to raw.githubusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 40448000 (39M) [application/octet-stream]
# Saving to: ‘maskdataset_3C.tarae.1’
#
# maskdataset_3C.tara 100%[===================>]  38.57M   127MB/s    in 0.3s
#
# 2026-08-25 01:18:19 (127 MB/s) - ‘maskdataset_3C.tarae.1’ saved [40448000/40448000]
#
# FINISHED --2026-08-25 01:18:19--
# Total wall clock time: 12s
# Downloaded: 5 files, 399M in 2.3s (172 MB/s)

# %% [markdown]
# * 현재 작업 경로

# %%
# %pwd
# Out:
# '/content'

# %% [markdown]
# * 다운로드 결과 확인

# %%
# !ls -l
# Out:
# total 408144
# -rw-r--r-- 1 root root 94371840 Aug 25 00:58 maskdataset_3C.taraa
# -rw-r--r-- 1 root root 94371840 Aug 25 00:58 maskdataset_3C.tarab
# -rw-r--r-- 1 root root 94371840 Aug 25 00:58 maskdataset_3C.tarac
# -rw-r--r-- 1 root root 94371840 Aug 25 00:58 maskdataset_3C.tarad
# -rw-r--r-- 1 root root 40448000 Aug 25 00:58 maskdataset_3C.tarae
# drwxr-xr-x 1 root root     4096 Aug 20 13:35 sample_data

# %% [markdown]
# >## 2) Unzip

# %%
# !cat maskdataset_3C.tar* | tar xf -
# Out:
# tar: Skipping to next header
# tar: Skipping to next header
# tar: Skipping to next header
# tar: Skipping to next header
# tar: Exiting with failure status due to previous errors

# %% [markdown]
# * 실행 결과 확인
#  - 'yolo_custom_modeling' 디렉토리 생성

# %%
# !ls -l
# Out:
# total 408148
# -rw-r--r-- 1 root root 94371840 May  2 04:49 maskdataset_3C.taraa
# -rw-r--r-- 1 root root 94371840 May  2 04:49 maskdataset_3C.tarab
# -rw-r--r-- 1 root root 94371840 May  2 04:49 maskdataset_3C.tarac
# -rw-r--r-- 1 root root 94371840 May  2 04:49 maskdataset_3C.tarad
# -rw-r--r-- 1 root root 40448000 May  2 04:49 maskdataset_3C.tarae
# drwxr-xr-x 1 root root     4096 Apr 30 13:37 sample_data
# drwxr-xr-x 3 root root     4096 Feb  2  2023 yolo_custom_modeling

# %% [markdown]
# # II. Train vs. Test Split

# %% [markdown]
# dataset/
# ├── images/
# │   ├── train/
# │   └── val/
# └── labels/
#     ├── train/
#     └── val/

# %% [markdown]
# * 현재 작업 경로

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# >## 1) Image Files

# %%
from glob import glob

img_list = glob('/content/yolo_custom_modeling/dataset/images/*.png')

print(len(img_list))
# Out:
# 843

# %% [markdown]
# >## 2) Label Files

# %%
from glob import glob

txt_list = glob('/content/yolo_custom_modeling/dataset/labels/*.txt')

print(len(txt_list))
# Out:
# 843

# %% [markdown]
# >## 3) train_test_split( )
#
# * 8:2

# %%
from sklearn.model_selection import train_test_split

train_img_list, valid_img_list = train_test_split(img_list,
                                                test_size = 0.2,
                                                random_state = 2045)

print(len(train_img_list), len(valid_img_list))
# Out:
# 674 169

# %% [markdown]
# * 목록 확인

# %%
print('Train_Img: ', train_img_list)
print('Valid_Img: ', valid_img_list)
# Out:
# Train_Img:  ['/content/yolo_custom_modeling/dataset/images/maksssksksss429.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss762.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss577.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss37.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss153.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss576.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss60.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss122.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss329.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss726.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss63.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss531.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss22.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss819.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss261.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss114.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss106.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss394.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss228.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss466.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss583.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss75.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss546.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss334.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss651.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss308.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss693.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss632.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss530.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss515.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss507.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss682.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss351.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss824.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss144.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss295.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss107.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss16.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss495.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss607.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss423.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss582.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss380.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss76.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss171.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss786.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss424.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss267.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss825.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss566.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss391.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss745.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss408.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss543.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss579.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss8.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss812.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss728.png', '/content/yolo_custom_modeling/dataset/images/maksss ...
# Valid_Img:  ['/content/yolo_custom_modeling/dataset/images/maksssksksss686.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss436.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss646.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss318.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss484.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss116.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss549.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss789.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss368.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss264.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss691.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss793.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss61.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss354.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss39.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss666.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss69.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss234.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss327.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss296.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss146.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss275.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss385.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss702.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss152.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss629.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss480.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss310.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss229.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss616.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss738.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss698.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss15.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss765.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss719.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss355.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss650.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss265.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss372.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss339.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss604.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss574.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss108.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss268.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss836.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss197.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss337.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss269.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss413.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss827.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss485.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss830.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss77.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss754.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss162.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss800.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss672.png', '/content/yolo_custom_modeling/dataset/images/maksssksksss103.png', '/content/yolo_custom_modeling/dataset/images/ma ...

# %% [markdown]
# >## 4) Train.txt & Valid.txt 생성

# %%
with open('/content/yolo_custom_modeling/dataset/Train.txt', 'w') as f:
  f.write('\n'.join(train_img_list) + '\n')

with open('/content/yolo_custom_modeling/dataset/Valid.txt', 'w') as f:
  f.write('\n'.join(valid_img_list) + '\n')

# %% [markdown]
# * 생성 확인

# %%
# !ls -l /content/yolo_custom_modeling/dataset/*.txt
# Out:
# -rw-r--r-- 1 root root 43718 Aug 25 01:34 /content/yolo_custom_modeling/dataset/Train.txt
# -rw-r--r-- 1 root root 10967 Aug 25 01:33 /content/yolo_custom_modeling/dataset/Valid.txt

# %% [markdown]
# >## 5) data.yaml 생성

# %%
yaml_text = """train: /content/yolo_custom_modeling/dataset/Train.txt
val: /content/yolo_custom_modeling/dataset/Valid.txt

nc: 3
names: ['mask', 'w_mask', 'no_mask']"""

with open('/content/yolo_custom_modeling/dataset/data.yaml', 'w') as file:
    file.write(yaml_text)

# %% [markdown]
# * 생성 확인

# %%
# %cat /content/yolo_custom_modeling/dataset/data.yaml
# Out:
# train: /content/yolo_custom_modeling/dataset/Train.txt
# val: /content/yolo_custom_modeling/dataset/Valid.txt
#
# nc: 3
# names: ['mask', 'w_mask', 'no_mask']

# %% [markdown]
# # III. Install YOLO_v8

# %% [markdown]
# https://github.com/ultralytics/ultralytics

# %%
# !pip install -q ultralytics

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.128 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 48.4/112.6 GB disk)

# %% [markdown]
# # IV. Model Learning

# %% [markdown]
# >## 1) YOLO_v8s

# %% [markdown]
# * yolov8s.pt
#  - 약 20분
#
# * https://docs.ultralytics.com/usage/cfg/
#
# * 학습이 모두 끝나면 현재 작업하고 있는 위치를 기준으로 최적의 성능을 낸 가중치 파일인 best.pt이  runs/detect/train/weights/best.pt 저장되여 있다.
#
# * 아래 코드를 여러번 실행하면 runs/detect/train/weights/best.pt에서 train2, train3...으로 생성이 된다.
# * 결과물을 저장할 위치를 직접 지정하는 방법(project/name 파라미터)
# ```
#     !yolo task = detect \
#       mode = train \
#       model = yolov8s.pt \
#       data = /content/yolo_custom_modeling/dataset/data.yaml \
#       epochs = 25 \
#       imgsz = 640 \
#       project = /content/my_experiment \    # 결과물이 저장될 최상위 폴더
#       name = mask_detection \              # 세부 프로젝트 폴더 이름
#       plots = True
# ```
#    위와 같이 설정하면 가중치가
#    **/content/my_experiment/mask_detection/weights/best.pt** 경로에 저장된다.

# %%
# %%time

# !yolo task = detect \
      mode = train \
      model = yolov8s.pt \
      data = /content/yolo_custom_modeling/dataset/data.yaml \
      epochs = 25 \
      imgsz = 640 \
      plots = True
# Out:
# Ultralytics 8.4.128 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, channels_last=False, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/yolo_custom_modeling/dataset/data.yaml, degrees=0.0, deterministic=True, device=, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=25, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8s.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/detect/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
#
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2117209  ultralytics.nn.modules.head.Detect           [3, 16, None, [128, 256, 512]]
# Model summary: 130 layers, 11,136,761 parameters, 11,136,745 gradients, 28.6 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: downloading yolo26n.pt for AMP checks (one-time, not used for training)...
#
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2833.2±534.1 MB/s, size: 403.5 KB)
#
# train: New cache created: /content/yolo_custom_modeling/dataset/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1554.3±1130.8 MB/s, size: 563.3 KB)
#
# val: New cache created: /content/yolo_custom_modeling/dataset/labels.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Plotting labels to /content/runs/detect/train/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/runs/detect/train
# Starting training for 25 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all        169        819      0.466      0.491      0.461      0.282
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all        169        819      0.483      0.523      0.522      0.318
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all        169        819      0.709      0.541      0.619      0.386
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all        169        819      0.712      0.592      0.647      0.414
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all        169        819      0.789      0.701       0.73      0.468
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all        169        819       0.78       0.67      0.735       0.47
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all        169        819      0.791      0.681      0.729      0.477
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all        169        819      0.767      0.694      0.746      0.486
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all        169        819      0.841      0.681      0.764      0.492
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all        169        819        0.8      0.743      0.766        0.5
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all        169        819      0.794      0.775      0.776      0.509
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all        169        819      0.829      0.742      0.804      0.533
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all        169        819      0.873      0.777      0.824      0.552
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all        169        819      0.905      0.776      0.829      0.549
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all        169        819      0.865      0.739       0.82      0.543
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all        169        819      0.868        0.7      0.782      0.517
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all        169        819       0.87      0.796      0.834      0.555
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all        169        819      0.899      0.716      0.836      0.545
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all        169        819      0.869      0.788      0.841      0.565
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all        169        819      0.832      0.821      0.854       0.58
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all        169        819      0.875      0.788      0.847      0.578
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all        169        819      0.894        0.8      0.864      0.588
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all        169        819      0.879      0.763      0.854      0.584
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all        169        819      0.893      0.765      0.851      0.583
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all        169        819      0.911      0.764      0.856       0.59
#
# 25 epochs completed in 0.124 hours.
# Optimizer stripped from /content/runs/detect/train/weights/last.pt, 22.5MB
# Optimizer stripped from /content/runs/detect/train/weights/best.pt, 22.5MB
#
# Validating /content/runs/detect/train/weights/best.pt...
# Ultralytics 8.4.128 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 11,126,745 parameters, 0 gradients, 28.4 GFLOPs
#
#                    all        169        819      0.912      0.763      0.856       0.59
#                   mask        156        675      0.949      0.904      0.962      0.681
#                 w_mask         21         30       0.94      0.567      0.687      0.457
#                no_mask         46        114      0.846       0.82       0.92      0.632
# Speed: 0.3ms preprocess, 5.1ms inference, 0.0ms loss, 3.8ms postprocess per image
# Results saved to /content/runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train
# CPU times: user 1.67 s, sys: 308 ms, total: 1.98 s
# Wall time: 8min 5s

# %% [markdown]
# > ## 2) Object Detection 결과 확인

# %% [markdown]
# >### (1) Loss & mAP

# %%
from IPython.display import Image

Image('/content/runs/detect/train/results.png')

# %% [markdown]
# >### (2) Training Results Visualization

# %%
import glob
from IPython.display import Image, display

for imageName in glob.glob('/content/runs/detect/train/v*.jpg'):
    display(Image(filename=imageName))
    print("\n")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # V. Model Validation

# %% [markdown]
# >## 1) Validation 데이터에 best.pt 적용

# %%
# !yolo task = detect \
      mode = val \
      model = /content/runs/detect/train/weights/best.pt \
      data = /content/yolo_custom_modeling/dataset/data.yaml
# Out:
# Ultralytics 8.3.123 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 11,126,745 parameters, 0 gradients, 28.4 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3176.5±1848.7 MB/s, size: 568.4 KB)
# val: Scanning /content/yolo_custom_modeling/dataset/labels.cache... 169 images, 0 backgrounds, 0 corrupt: 100% 169/169 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 11/11 [00:06<00:00,  1.81it/s]
#                    all        169        910      0.925      0.801        0.9      0.627
#                   mask        151        739      0.964      0.867      0.954      0.674
#                 w_mask         21         29      0.879      0.753      0.857      0.581
#                no_mask         57        142      0.933      0.784       0.89      0.625
# Speed: 4.3ms preprocess, 10.9ms inference, 0.0ms loss, 5.0ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# # VI. Model Test

# %% [markdown]
# >## 1) Test Directory
#  * --source /content/yolo_custom_modeling/dataset/test

# %%
# !yolo task = detect \
      mode = predict \
      model = /content/runs/detect/train/weights/best.pt \
      conf = 0.25 \
      source = /content/yolo_custom_modeling/dataset/test \
      save = True
# Out:
# Ultralytics 8.3.123 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 11,126,745 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/10 /content/yolo_custom_modeling/dataset/test/mask_test_1.png: 640x640 3 masks, 16.5ms
# image 2/10 /content/yolo_custom_modeling/dataset/test/mask_test_10.png: 640x448 1 mask, 1 no_mask, 38.5ms
# image 3/10 /content/yolo_custom_modeling/dataset/test/mask_test_2.png: 384x640 2 masks, 36.8ms
# image 4/10 /content/yolo_custom_modeling/dataset/test/mask_test_3.png: 640x512 1 mask, 51.9ms
# image 5/10 /content/yolo_custom_modeling/dataset/test/mask_test_4.png: 384x640 1 mask, 11.3ms
# image 6/10 /content/yolo_custom_modeling/dataset/test/mask_test_5.png: 384x640 18 masks, 1 w_mask, 1 no_mask, 10.7ms
# image 7/10 /content/yolo_custom_modeling/dataset/test/mask_test_6.png: 448x640 3 masks, 37.8ms
# image 8/10 /content/yolo_custom_modeling/dataset/test/mask_test_7.png: 384x640 4 masks, 11.4ms
# image 9/10 /content/yolo_custom_modeling/dataset/test/mask_test_8.png: 320x640 3 masks, 39.5ms
# image 10/10 /content/yolo_custom_modeling/dataset/test/mask_test_9.png: 640x512 1 mask, 12.7ms
# Speed: 2.3ms preprocess, 26.7ms inference, 15.4ms postprocess per image at shape (1, 3, 640, 512)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# >## 2) Results Visualization

# %%
# display inference on ALL test images

import glob
from IPython.display import Image, display

for imageName in glob.glob('/content/runs/detect/predict/*'): #assuming JPG
    display(Image(filename=imageName))
    print("\n")

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
